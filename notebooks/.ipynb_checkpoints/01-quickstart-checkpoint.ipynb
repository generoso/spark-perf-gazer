// %% [markdown]
// # PerfGazer Quickstart
//
// This notebook demonstrates how to set up and use PerfGazer to capture Spark performance metrics.
//
// **Works on:** Local (Almond/Jupyter) | Databricks

// %% [markdown]
// ## 1. Setup Dependencies
//
// Skip this cell on Databricks if PerfGazer is installed as a cluster library.

// %%
// Local setup only - load dependencies via Ammonite/Almond
import $ivy.`org.apache.spark::spark-sql:3.5.2`
import $ivy.`io.github.amadeusitgroup::perfgazer_spark_3-5-2:0.0.1`
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/sh/almond/almond-spark_2.12/0.14.0-RC8/almond-spark_2.12-0.14.0-RC8.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-sql_2.12/3.5.2/spark-sql_2.12-3.5.2.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-parent_2.12/3.5.2/spark-parent_2.12-3.5.2.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/apache/18/apache-18.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/parquet/parquet-hadoop/1.13.1/parquet-hadoop-1.13.1.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/orc/orc-mapreduce/1.9.4/orc-mapreduce-1.9.4.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/univocity/univocity-parsers/2.9.1/univocity-parsers-2.9.1.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-catalyst_2.12/3.5.2/spark-catalyst_2.12-3.5.2.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/fasterxml/jackson/core/jackson-databind/2.15.2/jackson-databind-2.15.2.pom
// ...

// %% [markdown]
// ## 2. Create SparkSession with PerfGazer
//
// PerfGazer is configured via Spark configuration properties:
// - `spark.extraListeners` - registers PerfGazer as a Spark listener
// - `spark.perfgazer.sink.class` - specifies where to write reports (JsonSink or LogSink)
// - `spark.perfgazer.sink.json.destination` - output directory for JSON reports

// %%
import org.apache.spark.sql.SparkSession

// Output directory for reports
val outputDir = "/tmp/perfgazer-demo"

val spark = SparkSession.builder()
  .appName("PerfGazer Demo")
  .master("local[*]")  // Remove this line on Databricks
  .config("spark.driver.memory", "2g")  // Remove on Databricks
  .config("spark.extraListeners", "com.amadeus.perfgazer.PerfGazer")
  .config("spark.perfgazer.sink.class", "com.amadeus.perfgazer.JsonSink")
  .config("spark.perfgazer.sink.json.destination", outputDir)
  .getOrCreate()

println(s"SparkSession created. Reports will be written to: $outputDir")
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
// 26/04/01 20:00:02 INFO SparkContext: Running Spark version 3.5.2
// 26/04/01 20:00:02 INFO SparkContext: OS info Linux, 6.11.3-200.fc40.aarch64, amd64
// 26/04/01 20:00:02 INFO SparkContext: Java version 1.8.0_442
// 26/04/01 20:00:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 26/04/01 20:00:02 INFO ResourceUtils: ==============================================================
// 26/04/01 20:00:02 INFO ResourceUtils: No custom resources configured for spark.driver.
// 26/04/01 20:00:02 INFO ResourceUtils: ==============================================================
// 26/04/01 20:00:02 INFO SparkContext: Submitted application: PerfGazer Demo
// ...

// %% [markdown]
// ## 3. Run Some Spark Operations
//
// PerfGazer automatically captures metrics for all Spark jobs, stages, and SQL queries.

// %%
import spark.implicits._

// Create a sample dataset
val data = spark.range(1, 1000000)
  .withColumn("category", ($"id" % 10).cast("string"))
  .withColumn("value", $"id" * 2)

// Trigger some Spark actions
val result = data
  .groupBy("category")
  .agg(
    org.apache.spark.sql.functions.count("*").as("count"),
    org.apache.spark.sql.functions.sum("value").as("total_value"),
    org.apache.spark.sql.functions.avg("value").as("avg_value")
  )
  .orderBy("category")

result.show()
// Out:
// 26/04/01 20:00:05 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
// 26/04/01 20:00:06 INFO SharedState: Warehouse path is 'file:/home/jovyan/work/notebooks/spark-warehouse'.
// 26/04/01 20:00:09 INFO CodeGenerator: Code generated in 487.381212 ms
// 26/04/01 20:00:10 INFO DAGScheduler: Registering RDD 3 (show at cmd3.sc:18) as input to shuffle 0
// 26/04/01 20:00:10 INFO DAGScheduler: Got map stage job 0 (show at cmd3.sc:18) with 5 output partitions
// 26/04/01 20:00:10 INFO DAGScheduler: Final stage: ShuffleMapStage 0 (show at cmd3.sc:18)
// 26/04/01 20:00:10 INFO DAGScheduler: Parents of final stage: List()
// 26/04/01 20:00:10 INFO DAGScheduler: Missing parents: List()
// 26/04/01 20:00:10 INFO DAGScheduler: Submitting ShuffleMapStage 0 (MapPartitionsRDD[3] at show at cmd3.sc:18), which has no missing parents
// ...

// %%
// Another operation - join example
val categories = Seq(
  ("0", "Category A"),
  ("1", "Category B"),
  ("2", "Category C")
).toDF("category", "name")

val joined = result.join(categories, "category")
joined.show()
// Out:
// 26/04/01 20:00:18 INFO CodeGenerator: Code generated in 49.832461 ms
// 26/04/01 20:00:19 INFO CodeGenerator: Code generated in 33.079056 ms
// 26/04/01 20:00:19 INFO CodeGenerator: Code generated in 12.45823 ms
// 26/04/01 20:00:19 INFO SparkContext: Starting job: $anonfun$withThreadLocalCaptured$1 at FutureTask.java:266
// 26/04/01 20:00:19 INFO DAGScheduler: Got job 2 ($anonfun$withThreadLocalCaptured$1 at FutureTask.java:266) with 3 output partitions
// 26/04/01 20:00:19 INFO DAGScheduler: Final stage: ResultStage 3 ($anonfun$withThreadLocalCaptured$1 at FutureTask.java:266)
// 26/04/01 20:00:19 INFO DAGScheduler: Parents of final stage: List()
// 26/04/01 20:00:19 INFO DAGScheduler: Missing parents: List()
// 26/04/01 20:00:19 INFO DAGScheduler: Submitting ResultStage 3 (MapPartitionsRDD[10] at $anonfun$withThreadLocalCaptured$1 at FutureTask.java:266), which has no missing parents
// ...

// %% [markdown]
// ## 4. View Generated Reports
//
// PerfGazer generates JSON reports for:
// - **SQL reports** - query-level metrics and execution plans
// - **Job reports** - job timing and stage information
// - **Stage reports** - detailed stage metrics

// %%
// List generated report files
import java.io.File

val reportFiles = new File(outputDir).listFiles()
  .filter(_.getName.endsWith(".json"))
  .map(_.getName)
  .sorted

println("Generated report files:")
reportFiles.foreach(println)
// Out:
// Generated report files:
// job-reports-f13934a5-741d-404b-b5d2-c0052685ebe2.json
// sql-reports-ba7888d7-c45e-45d6-9349-6e3076d68a8f.json
// stage-reports-253fac44-0e5e-4694-8084-fbe230b0d645.json
// task-reports-63f18677-8626-4649-97fa-9edf9c612ae7.json
// import java.io.File
// reportFiles: Array[String] = Array(
//   "job-reports-f13934a5-741d-404b-b5d2-c0052685ebe2.json",
//   "sql-reports-ba7888d7-c45e-45d6-9349-6e3076d68a8f.json",
//   "stage-reports-253fac44-0e5e-4694-8084-fbe230b0d645.json",
//   "task-reports-63f18677-8626-4649-97fa-9edf9c612ae7.json"
// )

// %% [markdown]
// ## 5. Query Reports with Spark SQL
//
// The reports are JSON files that can be queried directly with Spark.

// %%
// Create views for the reports
spark.sql(s"""
  CREATE OR REPLACE TEMPORARY VIEW job
  USING json
  OPTIONS (path '$outputDir/job-reports-*.json')
""")

spark.sql(s"""
  CREATE OR REPLACE TEMPORARY VIEW sql
  USING json
  OPTIONS (path '$outputDir/sql-reports-*.json')
""")

spark.sql(s"""
  CREATE OR REPLACE TEMPORARY VIEW stage
  USING json
  OPTIONS (path '$outputDir/stage-reports-*.json')
""")
// Out:
// 26/04/01 20:00:23 INFO InMemoryFileIndex: It took 21 ms to list leaf files for 1 paths.
// 26/04/01 20:00:24 INFO InMemoryFileIndex: It took 3 ms to list leaf files for 1 paths.
// 26/04/01 20:00:24 INFO FileSourceStrategy: Pushed Filters:
// 26/04/01 20:00:24 INFO FileSourceStrategy: Post-Scan Filters:
// 26/04/01 20:00:24 INFO MemoryStore: Block broadcast_6 stored as values in memory (estimated size 350.0 KiB, free 867.5 MiB)
// 26/04/01 20:00:24 INFO MemoryStore: Block broadcast_6_piece0 stored as bytes in memory (estimated size 34.2 KiB, free 867.5 MiB)
// 26/04/01 20:00:24 INFO BlockManagerInfo: Added broadcast_6_piece0 in memory on 929c957f24a6:38295 (size: 34.2 KiB, free: 875.9 MiB)
// 26/04/01 20:00:24 INFO SparkContext: Created broadcast 6 from sql at cmd6.sc:5
// 26/04/01 20:00:24 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
// ...

// %%
spark.start()
// Out:
// cmd13.sc:1: value start is not a member of org.apache.spark.sql.SparkSession
// val res13 = spark.start()
//                   ^
// Compilation Failed

// %%
// Query job reports
spark.sql("""
  SELECT 
    *
  FROM job

""").show(truncate = false)
// Out:
// 26/04/01 20:11:01 INFO FileSourceStrategy: Pushed Filters:
// 26/04/01 20:11:01 INFO FileSourceStrategy: Post-Scan Filters:
// java.lang.IllegalStateException: Cannot call methods on a stopped SparkContext.
// This stopped SparkContext was created at:
//
// org.apache.spark.sql.SparkSession$Builder.getOrCreate(SparkSession.scala:1093)
// ammonite.$sess.cmd2$Helper.<init>(cmd2.sc:12)
// ammonite.$sess.cmd2$.<init>(cmd2.sc:7)
// ammonite.$sess.cmd2$.<clinit>(cmd2.sc)
// ammonite.$sess.cmd2.$main(cmd2.sc)
// sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
// sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
// sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
// java.lang.reflect.Method.invoke(Method.java:498)
// ammonite.runtime.Evaluator$$anon$1.$anonfun$evalMain$1(Evaluator.scala:107)
// ammonite.util.Util$.withContextClassloader(Util.scala:21)
// ...

// %%
// Query SQL reports
spark.sql("""
  SELECT 
    sqlId,
    description
  FROM sql
  ORDER BY sqlId
""").show(truncate = false)

// %% [markdown]
// ## 6. Cleanup

// %%
spark.stop()

// %% [markdown]
// ## Configuration Reference
//
// | Property | Default | Description |
// |----------|---------|-------------|
// | `spark.perfgazer.sink.class` | (required) | Sink class: `JsonSink` or `LogSink` |
// | `spark.perfgazer.sink.json.destination` | (required for JsonSink) | Output directory |
// | `spark.perfgazer.sql.enabled` | `true` | Enable SQL reports |
// | `spark.perfgazer.jobs.enabled` | `true` | Enable job reports |
// | `spark.perfgazer.stages.enabled` | `true` | Enable stage reports |
// | `spark.perfgazer.tasks.enabled` | `false` | Enable task reports (verbose) |
// | `spark.perfgazer.max.cache.size` | `100` | Max events to cache per type |
